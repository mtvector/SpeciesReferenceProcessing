# %%
import pandas as pd
import os
genomes_tab=pd.read_csv(os.path.expanduser('~/Reference_Genome_tracking.csv'),sep=',',dtype='str')
genomes_tab['Species']=genomes_tab['Species'].str.replace(' ','_',regex=False)
genomes_tab.index=genomes_tab['Species']
genomes_tab=genomes_tab.loc[~genomes_tab.index.isna(),:]

# %%
from Bio import Entrez

def get_taxid(species_name):
    """Get the taxid for a species name using NCBI's Entrez Utilities."""
    Entrez.email = "your-email@example.com"  # Provide your email address
    handle = Entrez.esearch(db="taxonomy", term=species_name)
    record = Entrez.read(handle)
    handle.close()
    
    # Return the first TaxID found
    if record["IdList"]:
        return record["IdList"][0]
    else:
        return None

species_list = [
    "delphinus delphis", "delphinus capensis", "tursiops truncatus", 
    "stenella attenuata", "stenella longirostris", "stenella coeruleoalba", 
    "lagenorhynchus obliquidens", "steno bredanensis", "pseudoorca crassidens", 
    "peponocephala electra", "feresa attenuata", "globicephala macrorhynchus", 
    "globicephala melas", "grampus griseus", "orcinus orca", 
    "lissodelphis borealis", "phocoena phocoena", "phocoenoides dalli", 
    "ziphius cavirostris", "physeter macrocephalus", "kogia breviceps", 
    "kogia sima", "balaenoptera musculus", "balaenoptera acutorostrata", 
    "megaptera novaeangliae", "eschrichtius robustus", "mesoplodon densirostris", 
    "delphinapterus leucas", "monodon monoceros"
]

# Fetch TaxIDs
cetacean_dict = {get_taxid(species):species  for species in species_list}

for species, taxid in cetacean_dict.items():
    print(f"{species}: {taxid}")


species_dict=dict(zip([9668,9669, 246437, 10116, 13616, 27679,39432, 
                     9823, 9361, 9986, 60711, 9598, 
                     30608, 10181, 37293, 9545, 9544, 
                     10090, 30611, 9685, 9595, 9606, 
                     9483, 42100, 9515, 9614, 9407, 
                     9555, 9999, 9615, 7955,9739,9742,37347,9913,9913,9593,2715852,9612,9720,9704,9785,9778,9813,9818,319819,142885,9258],
                   ["Wild Ferret","Ferret", "Chinese.Treeshrew", "Rat", "Opossum", "Squirrel.monkey","Squirrel.monkey.sp", 
                     "Pig", "Armadillo.Nine.banded", "Rabbit", "African.green.monkey", "Chimpanzee", 
                     "Mouse.lemur", "Naked.mole.rat", "Owl.monkey", "Macaque.pig.tailed", "Macaque.rhesus", 
                     "Mouse", "Galago", "Cat", "Gorilla", "Human", 
                     "Marmoset", "Vaquita", "Tufted.capuchin", "Coyote", "Egyptian.fruit.bat", 
                     "Olive.baboon", "Squirrel.arctic.ground","Dog","Zebrafish",'Tursiops','Phocoena phocoena','Tupaia belangeri',
                   "Bos taurus",'Gorilla gorilla', 'Cebus imitator','Wolf','harbor seal','sea lion','Afr savannah elephant','manatee','hyrax','aardvark','hh tenrec','blind mole rat','','platypus']))

species_dict.update(cetacean_dict)
# Out:
# 9728: delphinus delphis
# 103584: delphinus capensis
# 9739: tursiops truncatus
# 9735: stenella attenuata
# 9736: stenella longirostris
# 9737: stenella coeruleoalba
# 90247: lagenorhynchus obliquidens
# 46167: steno bredanensis
# 82174: pseudoorca crassidens
# 103596: peponocephala electra
# 103592: feresa attenuata
# 38241: globicephala macrorhynchus
# 9731: globicephala melas
# 83653: grampus griseus
# 9733: orcinus orca
# 103588: lissodelphis borealis
# 9742: phocoena phocoena
# 9744: phocoenoides dalli
# 9760: ziphius cavirostris
# 9755: physeter macrocephalus
# 27615: kogia breviceps
# 9752: kogia sima
# 9771: balaenoptera musculus
# 9767: balaenoptera acutorostrata
# 9773: megaptera novaeangliae
# 9764: eschrichtius robustus
# 48708: mesoplodon densirostris
# 9749: delphinapterus leucas
# 40151: monodon monoceros

# %%
species_dict
# Out:
# {9668: 'Wild Ferret',
#  9669: 'Ferret',
#  246437: 'Chinese.Treeshrew',
#  10116: 'Rat',
#  13616: 'Opossum',
#  27679: 'Squirrel.monkey',
#  39432: 'Squirrel.monkey.sp',
#  9823: 'Pig',
#  9361: 'Armadillo.Nine.banded',
#  9986: 'Rabbit',
#  60711: 'African.green.monkey',
#  9598: 'Chimpanzee',
#  30608: 'Mouse.lemur',
#  10181: 'Naked.mole.rat',
#  37293: 'Owl.monkey',
#  9545: 'Macaque.pig.tailed',
#  9544: 'Macaque.rhesus',
#  10090: 'Mouse',
#  30611: 'Galago',
#  9685: 'Cat',
#  9595: 'Gorilla',
#  9606: 'Human',
#  9483: 'Marmoset',
#  42100: 'Vaquita',
#  9515: 'Tufted.capuchin',
#  9614: 'Coyote',
#  9407: 'Egyptian.fruit.bat',
#  9555: 'Olive.baboon',
#  9999: 'Squirrel.arctic.ground',
#  9615: 'Dog',
#  7955: 'Zebrafish',
#  9739: 'Tursiops',
#  9742: 'Phocoena phocoena',
#  37347: 'Tupaia belangeri',
#  9913: 'Gorilla gorilla',
#  9593: 'Cebus imitator',
#  2715852: 'Wolf',
#  9612: 'harbor seal',
#  9720: 'sea lion',
#  9704: 'Afr savannah elephant',
# ...

# %%
#Download all ncbi assemblies

from Bio import Entrez
import os
import requests
from ftplib import FTP
import re
import ftplib
import requests
import zipfile
import os
import shutil
import gzip
Entrez.email = "matthew.schmitz@alleninstitute.org"

def gzip_file(file_path):
    """Compresses a file using gzip."""
    with open(file_path, 'rb') as f_in:
        with gzip.open(file_path + '.gz', 'wb') as f_out:
            shutil.copyfileobj(f_in, f_out)
    os.remove(file_path)

def download_file(url, filename):
    response = requests.get(url, stream=True)
    if response.status_code == 200:
        with open(filename, 'wb') as f:
            f.write(response.content)
    else:
        print(f"Failed to download {url}")

def download_and_unzip(url, target_path, string_to_check):
    # Download the zip file
    response = requests.get(url)
    zip_file_path = os.path.join(target_path, 'downloaded_file.zip')
    with open(zip_file_path, 'wb') as f:
        f.write(response.content)

    # Unzip the file
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(target_path)

    # Move all files from subdirectories to the target directory and gzip if needed
    for root, dirs, files in os.walk(target_path):
        for file in files:
            file_path = os.path.join(root, file)
            if file_path != zip_file_path:  # Avoid moving the zip file itself
                # Check if the file needs to be gzipped
                shutil.move(file_path, os.path.join(target_path, file))
                if (string_to_check) in file and not file.endswith('.gz'):
                    gzip_file(os.path.join(target_path, file))

    # Remove the unzipped directory tree and the zip file
    for root, dirs, files in os.walk(target_path, topdown=False):
        for name in dirs:
            shutil.rmtree(os.path.join(root, name))
    os.remove(zip_file_path)

def find_files_in_directory(directory, file_extension):
    for file in os.listdir(directory):
        if re.search(file_extension, file):
            return file
    return None



def check_ftp_for_gtf(ftp_path):
    ftp_url = "ftp.ncbi.nlm.nih.gov"
    # Extract the relative path from the full FTP path
    relative_ftp_path = '/'.join(ftp_path.split('/')[3:])  # Remove the 'ftp://ftp.ncbi.nlm.nih.gov/' part
    
    try:
        with ftplib.FTP(ftp_url) as ftp:
            ftp.login()
            ftp.cwd(relative_ftp_path)
            files = ftp.nlst()
            for file in files:
                if file.endswith('.gtf.gz'):
                    return True
            return False
    except ftplib.all_errors as e:
        print(f"FTP error: {e}")
        return False

def sanitize_filename(filename):
    # Replace spaces with underscores
    filename = filename.replace(" ", "_")

    # Replace special characters with dashes
    # Define a regex pattern for unwanted characters
    pattern = r'[^\w\-_.]'
    filename = re.sub(pattern, '-', filename)

    return filename

def download_ftp_file(ftp_url, destination_filename):
    # Parse the FTP URL
    ftp_host, ftp_path = ftp_url.replace("ftp://", "").split("/", 1)

    # Connect to the FTP server
    with FTP(ftp_host) as ftp:
        ftp.login()
        
        # Ensure the directory for the file exists
        os.makedirs(os.path.dirname(destination_filename), exist_ok=True)

        # Download the file
        try:
            with open(destination_filename, 'wb') as local_file:
                ftp.retrbinary(f'RETR {ftp_path}', local_file.write)
        except Exception as e:
            print(f"Error downloading {ftp_url}: {e}")


def get_best_assembly_and_download(species_name,overall_path='',redownload=False):
    handle = Entrez.esummary(db="taxonomy", id=species_name)
    record = Entrez.read(handle)
    scientific_name = record[0]['ScientificName']

    handle = Entrez.esearch(db="assembly", term=f"{species_name}[Taxonomy ID]  AND (latest[filter] AND all[filter] NOT anomalous[filter]) AND (\"chromosome\"[Assembly Level] OR \"complete genome\"[Assembly Level] OR )", retmax=10)
    record = Entrez.read(handle)
    best_assembly = None
    best_assembly_gtf = None
    max_contig_n50 = 0
    max_contig_n50_ref = 0
    for assembly_id in record['IdList']:
        summary_handle = Entrez.esummary(db="assembly", id=assembly_id)
        summary = Entrez.read(summary_handle)
        doc_summary = summary['DocumentSummarySet']['DocumentSummary'][0]
        contig_n50 = int(doc_summary['ContigN50'])
        if contig_n50 > max_contig_n50:
            best_assembly = doc_summary
            max_contig_n50 = contig_n50
        if check_ftp_for_gtf(doc_summary['FtpPath_GenBank']) and (contig_n50 > max_contig_n50_ref):
            best_assembly_gtf=doc_summary
            max_contig_n50_ref = contig_n50

    
    if not best_assembly:
        print(f"No suitable assembly found for {species_name}")
        return

    make_two=False
    if best_assembly_gtf is not None:
        if best_assembly['FtpPath_Assembly_rpt'] != best_assembly_gtf['FtpPath_Assembly_rpt']:
            print('No GTF')
            make_two=True
    
    print(f"Best assembly for {species_name}: {best_assembly['AssemblyAccession']}")


    if make_two:
        assemblies={'best':best_assembly,'reference':best_assembly_gtf}
    elif best_assembly_gtf is None:
        assemblies={'best':best_assembly}
    else:
        assemblies={'reference':best_assembly_gtf}
        
    for d in assemblies.keys():
        print(d)
        dirname=os.path.join(str(species_name)+"-"+sanitize_filename(scientific_name),d)
        cur_assembly=assemblies[d]
           
        # Downloading the FASTA file
        print(cur_assembly['FtpPath_Assembly_rpt'])
        stat_ftp_url = cur_assembly['FtpPath_Assembly_rpt']
        stat_name=sanitize_filename(os.path.basename(stat_ftp_url))#sanitize_filename(f"{species_name}_assembly_report.txt")
        stat_destination = os.path.join(overall_path,dirname,stat_name)
        download_ftp_file(stat_ftp_url, stat_destination)

        fasta_ftp_url = re.sub('_assembly_report\.txt','_genomic.fna.gz',cur_assembly['FtpPath_Assembly_rpt'])
        fasta_name=sanitize_filename(os.path.basename(fasta_ftp_url))#sanitize_filename(f"{species_name}_genomic.fna.gz")
        fasta_destination = os.path.join(overall_path,dirname,fasta_name)
        if not redownload and os.path.exists(fasta_destination):
            continue
        download_ftp_file(fasta_ftp_url, fasta_destination)
        if d != 'best':
            gtf_ftp_url = re.sub('_assembly_report\.txt','_genomic.gtf.gz',cur_assembly['FtpPath_Assembly_rpt'])
            gtf_name=sanitize_filename(os.path.basename(gtf_ftp_url))#sanitize_filename(f"{species_name}_genomic.gtf.gz")
            gtf_destination = os.path.join(overall_path,dirname,gtf_name)
            #gtf_destination = f"{species_name}/{species_name}_genomic.gtf.gz"
            download_ftp_file(gtf_ftp_url, gtf_destination)
        else:
            try:
                url=f"https://api.ncbi.nlm.nih.gov/datasets/v2alpha/genome/accession/{cur_assembly['AssemblyAccession']}/download?include_annotation_type=GENOME_GTF,SEQUENCE_REPORT&filename={cur_assembly['AssemblyAccession']}.zip"
                print(url)
                print(os.path.join(overall_path,dirname))
                download_and_unzip(url, os.path.join(overall_path,dirname),'.gtf')
            except:
                pass
                

species_list = species_dict.keys()
#species_list=[9598]
#species_list=[10116]
for species in species_list:
    try:
        best_assembly=get_best_assembly_and_download(species,
                                                     overall_path='/home/matthew.schmitz/Matthew/genome/ncbi',
                                                    redownload=False)
    except:
        print(species, 'exploded')
# Out:
# No suitable assembly found for 9668
# No suitable assembly found for 9669
# Best assembly for 246437: GCA_033439345.1
# best
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/033/439/345/GCA_033439345.1_KIZ_version_2/GCA_033439345.1_KIZ_version_2_assembly_report.txt
# No GTF
# Best assembly for 10116: GCA_021556685.1
# best
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/021/556/685/GCA_021556685.1_UTH_Rnor_SHRSP_BbbUtx_1.0/GCA_021556685.1_UTH_Rnor_SHRSP_BbbUtx_1.0_assembly_report.txt
# reference
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/015/227/675/GCF_015227675.2_mRatBN7.2/GCF_015227675.2_mRatBN7.2_assembly_report.txt
# Best assembly for 13616: GCF_027887165.1
# best
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/027/887/165/GCF_027887165.1_mMonDom1.pri/GCF_027887165.1_mMonDom1.pri_assembly_report.txt
# No suitable assembly found for 27679
# No suitable assembly found for 39432
# Best assembly for 9823: GCA_030704935.1
# best
# ...

# %%
best_assembly=get_best_assembly_and_download(127582,
                                             overall_path='/home/matthew.schmitz/Matthew/genome/ncbi',
                                            redownload=False)
# Out:
# No suitable assembly found for 127582

# %%
#Download all ensembl assemblies
import requests
import os
import re
from ftplib import FTP

def sanitize_filename(filename):
    # Replace spaces with underscores and special characters with dashes
    filename = filename.replace(" ", "_")
    pattern = r'[^\w\-_.]'
    return re.sub(pattern, '-', filename)

def download_ftp_file(ftp_url, destination_filename):
    # Parse and download from FTP URL
    ftp_host, ftp_path = ftp_url.replace("ftp://", "").split("/", 1)
    with FTP(ftp_host) as ftp:
        ftp.login()
        os.makedirs(os.path.dirname(destination_filename), exist_ok=True)
        try:
            with open(destination_filename, 'wb') as local_file:
                ftp.retrbinary(f'RETR {ftp_path}', local_file.write)
        except Exception as e:
            print(f"Error downloading {ftp_url}: {e}")

def get_species_name(tax_id):
    """ Fetch species name using taxonomic ID from Ensembl """
    url = f"https://rest.ensembl.org/taxonomy/id/{tax_id}?content-type=application/json"
    response = requests.get(url)
    return response.json()['scientific_name']

def find_matching_files(ftp, path, patterns):
    """ Find files matching given patterns """
    ftp.cwd(path)
    files = ftp.nlst()
    matched_files = [file for file in files if any(pattern in file for pattern in patterns)]
    return matched_files

def download_ensembl_files(tax_id, path,redownload=False):
    species_name = get_species_name(tax_id)
    species_path = species_name.lower().replace(' ', '_')

    # Fetch genome information from Ensembl
    url = f"https://rest.ensembl.org/info/genomes/{species_path}?content-type=application/json"
    print(url)
    response = requests.get(url)
    data = response.json()
    assembly_name = data['assembly_name']

    # Prepare directory name
    dir_name = sanitize_filename(f"{tax_id}-{species_name}")
    dir_path = os.path.join(path, dir_name)
    os.makedirs(dir_path, exist_ok=True)

    # Prepare FTP paths
    ensembl_ftp_base = "ftp.ensembl.org"
    fasta_ftp_dir = f"/pub/release-110/fasta/{species_path}/dna/"
    gtf_ftp_dir = f"/pub/release-110/gtf/{species_path}/"

    with FTP(ensembl_ftp_base) as ftp:
        ftp.login()

        # Find matching FASTA and GTF files
        fa_patterns = [".dna_sm.toplevel.fa.gz"]
        gtf_patterns = [".gtf.gz"]
        unwanted_patterns = ["chr", "hapl", "abinitio"]

        fasta_files = find_matching_files(ftp, fasta_ftp_dir, fa_patterns)
        gtf_files = find_matching_files(ftp, gtf_ftp_dir, gtf_patterns)
        fasta_files = [f for f in fasta_files if not any(p in f for p in unwanted_patterns)]
        gtf_files = [f for f in gtf_files if not any(p in f for p in unwanted_patterns)]
        if not redownload and os.path.exists(os.path.join(dir_path, fasta_files[0])):
            return None
        # Download files
        if fasta_files:
            download_ftp_file(f"ftp://{ensembl_ftp_base}{fasta_ftp_dir}{fasta_files[0]}", os.path.join(dir_path, fasta_files[0]))
        if gtf_files:
            download_ftp_file(f"ftp://{ensembl_ftp_base}{gtf_ftp_dir}{gtf_files[0]}", os.path.join(dir_path, gtf_files[0]))



species_list = species_dict.keys()
#species_list=[str(x) for x in species_list]
for species in species_list:
    #download_ensembl_files(species, '/home/matthew.schmitz/Matthew/genome/ensembl')
    try:
        download_ensembl_files(species, '/home/matthew.schmitz/Matthew/genome/ensembl',redownload=False)
    except:
        print(species,'failed')
# Out:
# https://rest.ensembl.org/info/genomes/mustela_putorius?content-type=application/json
# 9668 failed
# https://rest.ensembl.org/info/genomes/mustela_putorius_furo?content-type=application/json
# https://rest.ensembl.org/info/genomes/tupaia_chinensis?content-type=application/json
# 246437 failed
# https://rest.ensembl.org/info/genomes/rattus_norvegicus?content-type=application/json
# https://rest.ensembl.org/info/genomes/monodelphis_domestica?content-type=application/json
# https://rest.ensembl.org/info/genomes/saimiri_boliviensis?content-type=application/json
# 27679 failed
# https://rest.ensembl.org/info/genomes/saimiri_boliviensis_boliviensis?content-type=application/json
# https://rest.ensembl.org/info/genomes/sus_scrofa?content-type=application/json
# https://rest.ensembl.org/info/genomes/dasypus_novemcinctus?content-type=application/json
# https://rest.ensembl.org/info/genomes/oryctolagus_cuniculus?content-type=application/json
# ...

# %%
import os
import pandas as pd
from Bio import SeqIO
import gtfparse
import re
import gzip

def is_gzipped(file_path):
    """ Check if the file is gzipped """
    with open(file_path, 'rb') as f:
        return f.read(2) == b'\x1f\x8b'

def calculate_N50(fasta_path):
    file_open_func = gzip.open if is_gzipped(fasta_path) else open
    with file_open_func(fasta_path, "rt") as handle:
        lengths = [len(rec) for rec in SeqIO.parse(handle, "fasta")]
    total_len = sum(lengths)
    lengths.sort(reverse=True)
    cumsum = 0
    for length in lengths:
        cumsum += length
        if cumsum >= total_len / 2:
            return length
    return 0

"""
def count_genes_transcripts(gtf_path):
    db = gffutils.create_db(gtf_path, dbfn=":memory:", force=True, keep_order=True, merge_strategy='merge', sort_attribute_values=True)
    num_genes = len(set(db.features_of_type('gene_id')))
    num_transcripts = len(set(db.features_of_type('transcript_id')))
    return num_genes, num_transcripts
"""

def count_genes_transcripts(gtf_path):
    try:
        gtf_df = gtfparse.read_gtf(gtf_path)
        num_genes = len(gtf_df['gene_id'].unique())
        try:
            num_transcripts = len(gtf_df['transcript_id'].unique())
        except:
            num_transcripts = num_genes
        return num_genes, num_transcripts
    except:
        return 0,0

def find_files_in_directory(directory, file_extension):
    for file in os.listdir(directory):
        if re.search(file_extension, file):
            return file
    return None

def process_directory(dir_path,gtf=False):
    for root, dirs, files in os.walk(dir_path):
        for dir_name in dirs:
            #try:
            dir_full_path = os.path.join(root, dir_name)
            #taxid, species_name = dir_name.split('-', 1)
            try:
                taxid, species_name =re.search('([0-9]+-[A-Za-z_]+)',dir_full_path).group(0).split('-',1)
                common_name = species_name.replace("_", " ")
            except:
                continue
            print(species_name)
            # Find the FASTA and GTF files
            fasta_file = find_files_in_directory(dir_full_path, r'\.f(n)?a(\.gz)?$')
            print(fasta_file)
            if not fasta_file:
                continue

            fasta_path = os.path.join(dir_full_path, fasta_file)

            # Read assembly name for NCBI
            assembly_name = fasta_file
            assembly_report_path = os.path.join(dir_full_path, f"{taxid}_assembly_report.txt")
            if os.path.exists(assembly_report_path):
                with open(assembly_report_path) as f:
                    for line in f:
                        if 'Assembly name' in line:
                            assembly_name = line.split(':')[1].strip()
                            break
                      
            n50 = calculate_N50(fasta_path)
            gtf_file = find_files_in_directory(dir_full_path, r'\.gtf')
            if gtf and (gtf_file is not None):
                gtf_path = os.path.join(dir_full_path, gtf_file)
                num_genes, num_transcripts = count_genes_transcripts(gtf_path)
            else:
                gtf_file = gtf_file
                gtf_path = os.path.join(dir_full_path, gtf_file if gtf_file is not None else '')
                num_genes = None
                num_transcripts = None
            
            stat_dict = {
                'Species': species_name,
                'TaxID': taxid,
                'Common Name': common_name,
                'Genome Assembly Name': assembly_name,
                'N50': n50,
                'Number of Genes': num_genes,
                'Number of Transcripts': num_transcripts,
                'FASTA File': fasta_file,
                'FASTA Path': fasta_path,
                'GTF File': gtf_file,
                'GTF Path': gtf_path
            }
            yield stat_dict
            #except:
            #    yield None

ensembl_data = list(process_directory('/home/matthew.schmitz/Matthew/genome/ensembl',gtf=True))
ncbi_data = list(process_directory('/home/matthew.schmitz/Matthew/genome/ncbi',gtf=True))
other_data = list(process_directory('/home/matthew.schmitz/Matthew/genome/other',gtf=True))

ensembl_data = [x for x in ensembl_data if x is not None]
ncbi_data = [x for x in ncbi_data if x is not None]
other_data = [x for x in other_data if x is not None]

# Create DataFrames
ensembl_df = pd.DataFrame(ensembl_data)
ncbi_df = pd.DataFrame(ncbi_data)
other_df = pd.DataFrame(other_data)

# Combine DataFrames
combined_df = pd.concat([ensembl_df, ncbi_df, other_df])
print(combined_df)
combined_df.to_csv('./AllGenomesData.csv')
# Out:
# Sus_scrofa
# Sus_scrofa.Sscrofa11.1.dna_sm.toplevel.fa.gz
# Polars found a filename. Ensure you pass a path to the file instead of a python file object when possible for best performance.
# INFO:root:Extracted GTF attributes: ['gene_id', 'gene_version', 'gene_name', 'gene_source', 'gene_biotype', 'transcript_id', 'transcript_version', 'transcript_name', 'transcript_source', 'transcript_biotype', 'exon_number', 'exon_id', 'exon_version', 'protein_id', 'protein_version', 'tag', 'projection_parent_transcript']
# Gorilla_gorilla_gorilla
# None
# Mus_musculus
# Mus_musculus.GRCm39.dna_sm.toplevel.fa.gz
# Polars found a filename. Ensure you pass a path to the file instead of a python file object when possible for best performance.
# ...

# %%
combined_df = pd.read_csv('./AllGenomesData.csv',sep=',',index_col=0)

# %%
combined_df.index=list(range(combined_df.shape[0]))

# %%
combined_df=combined_df.loc[~combined_df['TaxID'].isna(),:]

# %%
combined_df.sort_values('N50')
# Out:
#                    Species   TaxID             Common Name  \
# 0               Sus_scrofa    9823              Sus scrofa
# 1             Mus_musculus   10090            Mus musculus
# 2       Callithrix_jacchus    9483      Callithrix jacchus
# 3              Danio_rerio    7955             Danio rerio
# 4       Otolemur_garnettii   30611      Otolemur garnettii
# ..                     ...     ...                     ...
# 77  Megaptera_novaeangliae    9773  Megaptera novaeangliae
# 78      Trichechus_manatus  127582      Trichechus manatus
# 79   Rousettus_aegyptiacus    9407   Rousettus aegyptiacus
# 80        Tupaia_belangeri   37347        Tupaia belangeri
# 81          Macaca_mulatta    9544          Macaca mulatta
#
#                                  Genome Assembly Name  N50  Number of Genes  \
# 0        Sus_scrofa.Sscrofa11.1.dna_sm.toplevel.fa.gz  NaN              NaN
# 1           Mus_musculus.GRCm39.dna_sm.toplevel.fa.gz  NaN              NaN
# ...

# %%
import pandas as pd
from ete3 import Tree
import copy

def get_genera_from_species_list(species_list):
    """Extract genera from a list of species' scientific names."""
    return set(species.split()[0] for species in species_list)

def prune_tree(newick_tree_path, genera):
    """Prune the tree to retain only species from the specified genera."""
    tree = Tree(newick_tree_path,format=1)
    original_tree = copy.deepcopy(tree)
    for leaf in tree.iter_leaves():
        genus = leaf.name.split()[0]
        if genus not in genera:
            leaf.delete()
    return tree,original_tree

# Assuming DataFrame is loaded from a CSV or created from process_directory
# df = pd.read_csv('your_dataframe.csv')  # Load your DataFrame here

# Extract list of species and genera
species_list = [x.replace(' ','_') for x in  combined_df['Species'].tolist()]
print(species_list)
genera = get_genera_from_species_list(species_list)

# Path to your Newick tree
newick_tree_path = '/home/matthew.schmitz/Matthew/genome/hal/241-mammalian-2020v2.phast-242.nh'

# Prune the tree
pruned_tree, original_tree = prune_tree(newick_tree_path, genera)

# Optionally, save the pruned tree to a file
pruned_tree.write(outfile="/home/matthew.schmitz/Matthew/genome/hal/pruned_tree.nwk")

# Display the pruned tree (optional)
print(pruned_tree)
# Out:
# ['Sus_scrofa', 'Mus_musculus', 'Callithrix_jacchus', 'Danio_rerio', 'Otolemur_garnettii', 'Mustela_putorius_furo', 'Canis_lupus_familiaris', 'Procavia_capensis', 'Bos_taurus', 'Chlorocebus_sabaeus', 'Rattus_norvegicus', 'Macaca_nemestrina', 'Loxodonta_africana', 'Felis_catus', 'Zalophus_californianus', 'Delphinapterus_leucas', 'Balaenoptera_musculus', 'Cebus_imitator', 'Dasypus_novemcinctus', 'Monodelphis_domestica', 'Gorilla_gorilla', 'Physeter_catodon', 'Microcebus_murinus', 'Homo_sapiens', 'Saimiri_boliviensis_boliviensis', 'Macaca_mulatta', 'Urocitellus_parryii', 'Papio_anubis', 'Tupaia_belangeri', 'Aotus_nancymaae', 'Oryctolagus_cuniculus', 'Monodon_monoceros', 'Pan_troglodytes', 'Phocoena_sinus', 'Tursiops_truncatus', 'Stenella_coeruleoalba', 'Canis_lupus', 'Sus_scrofa', 'Gorilla_gorilla_gorilla', 'Mus_musculus', 'Callithrix_jacchus', 'Danio_rerio', 'Canis_lupus_familiaris', 'Bos_taurus', 'Bos_taurus', 'Chlorocebus_sabaeus', 'Eschrichtius_robustus', 'Balaenoptera_acutorostrata'
# ...

# %%
from ete3 import Tree

def get_species_not_in_tree(species_list, tree):
    # Extract species names from the tree
    species_in_tree = set(leaf.name for leaf in tree.iter_leaves())

    # Find species not in the tree
    species_not_in_tree = [species for species in species_list if species not in species_in_tree]

    return species_not_in_tree

# Example usage
species_list = [
    "delphinus delphis", "delphinus capensis", "tursiops truncatus",
    # ... other species ...
    "monodon monoceros"
]

#newick_tree = "(delphinus delphis, (tursiops truncatus, monodon monoceros));"  # Replace with your actual Newick tree
#tree = Tree(newick_tree)

# Find species not in the tree
species_not_in_tree = get_species_not_in_tree(combined_df['Species'], pruned_tree)
print("Species not in the tree:", species_not_in_tree)
# Out:
# Species not in the tree: ['Danio_rerio', 'Mustela_putorius_furo', 'Balaenoptera_musculus', 'Cebus_imitator', 'Monodelphis_domestica', 'Physeter_catodon', 'Saimiri_boliviensis_boliviensis', 'Urocitellus_parryii', 'Tupaia_belangeri', 'Phocoena_sinus', 'Stenella_coeruleoalba', 'Gorilla_gorilla_gorilla', 'Danio_rerio', 'Ornithorhynchus_anatinus', 'Globicephala_melas', 'Delphinus_delphis', 'Balaenoptera_musculus', 'Steno_bredanensis', 'Mesoplodon_densirostris', 'Monodelphis_domestica', 'Physeter_catodon', 'Grampus_griseus', 'Phocoena_sinus', 'Megaptera_novaeangliae', 'Tupaia_belangeri']

# %%
from ete3 import Tree

def add_node_to_common_ancestor(tree, new_node_name, existing_node_names):
    all_nodes = [node.name for node in tree.traverse()]
    if new_node_name in all_nodes:
        print(new_node_name,'is in the tree already!')
        return None
    # Find the common ancestor of the existing nodes
    common_ancestor = tree.get_common_ancestor(existing_node_names)

    # Calculate the mean branch length to the common ancestor
    branch_lengths = [tree.get_distance(name,common_ancestor) for name in existing_node_names]
    mean_branch_length = sum(branch_lengths) / len(branch_lengths)

    # Create the new node and add it to the common ancestor
    new_node = common_ancestor.add_child(name=new_node_name, dist=mean_branch_length)
    
    return new_node

# Add the new node
add_node_to_common_ancestor(pruned_tree, 'Danio_rerio', ['Dasypus_novemcinctus','Otolemur_garnettii'])
add_node_to_common_ancestor(pruned_tree, 'Tupaia_belangeri', ['Tupaia_chinensis','Callithrix_jacchus'])
add_node_to_common_ancestor(pruned_tree, 'Mustela_putorius_furo', ['Canis_lupus_familiaris','Felis_catus'])
add_node_to_common_ancestor(pruned_tree, 'Monodelphis_domestica', ['Dasypus_novemcinctus','Otolemur_garnettii'])
add_node_to_common_ancestor(pruned_tree, 'Urocitellus_parryii', ['Rattus_norvegicus','Mus_musculus'])
add_node_to_common_ancestor(pruned_tree, 'Phocoena_sinus', ['Orcinus_orca','Tursiops_truncatus'])
add_node_to_common_ancestor(pruned_tree, 'Stenella_coeruleoalba', ['Orcinus_orca','Tursiops_truncatus'])
add_node_to_common_ancestor(pruned_tree, 'Globicephala_melas', ['Orcinus_orca','Tursiops_truncatus'])
add_node_to_common_ancestor(pruned_tree, 'Delphinus_delphis', ['Orcinus_orca','Tursiops_truncatus'])
add_node_to_common_ancestor(pruned_tree, 'Steno_bredanensis', ['Orcinus_orca','Tursiops_truncatus'])
add_node_to_common_ancestor(pruned_tree, 'Grampus_griseus', ['Orcinus_orca','Tursiops_truncatus'])
add_node_to_common_ancestor(pruned_tree, 'Physeter_catodon', ['Orcinus_orca','Tursiops_truncatus'])
add_node_to_common_ancestor(pruned_tree, 'Gorilla_gorilla_gorilla', ['Homo_sapiens','Pan_troglodytes'])
# Out:
# Danio_rerio is in the tree already!
# Tupaia_belangeri is in the tree already!
# Mustela_putorius_furo is in the tree already!
# Monodelphis_domestica is in the tree already!
# Urocitellus_parryii is in the tree already!
# Phocoena_sinus is in the tree already!
# Stenella_coeruleoalba is in the tree already!
# Globicephala_melas is in the tree already!
# Delphinus_delphis is in the tree already!
# Steno_bredanensis is in the tree already!
# Grampus_griseus is in the tree already!
# Physeter_catodon is in the tree already!
# Gorilla_gorilla_gorilla is in the tree already!

# %%
fix_tree=Tree('((((((((((Otolemur_garnettii:0.0477624,Microcebus_murinus:0.0231249)1:0.0417511,(((((Macaca_nemestrina:0.00360292,Macaca_mulatta:0.002437)1:0.0042712,Papio_anubis:0.0062452)1:0.00406285,Chlorocebus_sabaeus:0.00521092)1:0.00497113,((((Homo_sapiens:0.00596652,(Pan_troglodytes,Pan_paniscus):0.00186328),Gorilla_gorilla_gorilla:0.0039149)1:0.00180399)1:0.01633, Pongo_abelii)),((Aotus_nancymaae,(Saimiri_boliviensis_boliviensis,(Cebus_imitator,Sapajus_apella))):0.0219195,Callithrix_jacchus:0.0215731)1:0.000848199)1:0.0781501)1:0.0179149,(Tupaia_chinensis:0.024326,Tupaia_belangeri:0.0714062))1:0.00425506,(((Spalax_microphthalmus,Heterocephalus_glaber):0.0546792,((Rattus_norvegicus:0.0874217,Mus_musculus:0.00924972),Urocitellus_parryii:0.0483357)1:0.0570242)1:0.0368586,Oryctolagus_cuniculus:0.0240056)1:0.0119995)1:0.0309181,((((((((((Tursiops_truncatus:0.00604089,Stenella_coeruleoalba:0.00575805,Delphinus_delphis:0.00575805),((((Globicephala_macrorhynchus,Globicephala_melas),Pseudorca_crassidens):0.00575805,Steno_bredanensis):0.00575805,Grampus_griseus:0.00575805)),Orcinus_orca:0.00547522),Phocoena_sinus:0.00575805),Mesoplodon_densirostris),((Kogia_breviceps,Kogia_sima),Physeter_catodon):0.00575805)1:0.00540204,(((Balaenoptera_musculus,Balaenoptera_acutorostrata),Megaptera_Novaeangliae),Eschrichtius_robustus)),Bos_taurus:0.00179196)1:0.0168069,Sus_scrofa:0.0546012)1:0.00922581,(Felis_catus:0.0044349,((((Canis_lupus_familiaris,Canis_lupus),Canis_latrans)):0.000719825,(Mustela_putorius_furo,(Phoca_vitulina,Zalophus_californianus))):0.00257736)1:0.054329,Rousettus_aegyptiacus)1:0.00390038)1:0.0186332,Dasypus_novemcinctus:0.0756033), ((Orycteropus_afer,Setifer_setosus),(Procavia_capensis,(Loxodonta_africana, Trichechus_manatus)))),Monodelphis_domestica:0.118419),Ornithorhynchus_anatinus),Danio_rerio:0.118419);')

# %%
print(fix_tree)
# Out:
#                               /-Otolemur_garnettii
#                            /-|
#                           |   \-Microcebus_murinus
#                           |
#                           |               /-Macaca_nemestrina
#                           |            /-|
#                           |         /-|   \-Macaca_mulatta
#                           |        |  |
#                           |      /-|   \-Papio_anubis
#                           |     |  |
#                         /-|     |   \-Chlorocebus_sabaeus
#                        |  |     |
#                        |  |   /-|            /-Homo_sapiens
#                        |  |  |  |         /-|
#                        |  |  |  |        |  |   /-Pan_troglodytes
#                        |  |  |  |   /- /-|   \-|
#                        |  |  |  |  |     |      \-Pan_paniscus
#                        |  |  |   \-|     |
#                        |  |  |     |      \-Gorilla_gorilla_gorilla
# ...

# %%
species_list = [x.replace(' ','_') for x in  combined_df['Species'].tolist()]
genera = get_genera_from_species_list(species_list)

# Path to your Newick tree
newick_tree_path = '/home/matthew.schmitz/Matthew/genome/hal/fixed_tree.nwk'

# Prune the tree
fixed_pruned_tree, original_tree = prune_tree(newick_tree_path, genera)

# Optionally, save the pruned tree to a file
fixed_pruned_tree.write(outfile="/home/matthew.schmitz/Matthew/genome/hal/fixed_pruned_tree.nwk")

print(fixed_pruned_tree)
# Out:
#                               /-Otolemur_garnettii
#                            /-|
#                           |   \-Microcebus_murinus
#                           |
#                           |               /-Macaca_nemestrina
#                           |            /-|
#                           |         /-|   \-Macaca_mulatta
#                           |        |  |
#                         /-|      /-|   \-Papio_anubis
#                        |  |     |  |
#                        |  |     |   \-Chlorocebus_sabaeus
#                        |  |   /-|
#                        |  |  |  |         /-Homo_sapiens
#                        |  |  |  |      /-|
#                        |  |  |   \- /-|   \-Pan_troglodytes
#                        |  |  |        |
#                        |   \-|         \-Gorilla_gorilla_gorilla
#                      /-|     |
#                     |  |     |      /-Aotus_nancymaae
#                     |  |     |   /-|
# ...

# %%
combined_df=combined_df.loc[combined_df.groupby('Species')['N50'].idxmax(),:]
# Out:
# /scratch/fast/11984821/ipykernel_314158/1683586196.py:1: FutureWarning: The behavior of Series.idxmax with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   combined_df.groupby('Species')['N50'].idxmax()
# /scratch/fast/11984821/ipykernel_314158/1683586196.py:1: FutureWarning: The behavior of Series.idxmax with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   combined_df.groupby('Species')['N50'].idxmax()
# /scratch/fast/11984821/ipykernel_314158/1683586196.py:1: FutureWarning: The behavior of Series.idxmax with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   combined_df.groupby('Species')['N50'].idxmax()
# ...

# %%
print(combined_df)
# Out:
#                    Species   TaxID             Common Name  \
# 0               Sus_scrofa    9823              Sus scrofa
# 1             Mus_musculus   10090            Mus musculus
# 2       Callithrix_jacchus    9483      Callithrix jacchus
# 3              Danio_rerio    7955             Danio rerio
# 4       Otolemur_garnettii   30611      Otolemur garnettii
# ..                     ...     ...                     ...
# 0   Megaptera_novaeangliae    9773  Megaptera novaeangliae
# 1       Trichechus_manatus  127582      Trichechus manatus
# 2    Rousettus_aegyptiacus    9407   Rousettus aegyptiacus
# 3         Tupaia_belangeri   37347        Tupaia belangeri
# 4           Macaca_mulatta    9544          Macaca mulatta
#
#                                  Genome Assembly Name  N50  Number of Genes  \
# 0        Sus_scrofa.Sscrofa11.1.dna_sm.toplevel.fa.gz  NaN              NaN
# 1           Mus_musculus.GRCm39.dna_sm.toplevel.fa.gz  NaN              NaN
# ...

# %%
 import pandas as pd

def write_tree_and_dataframe_to_file(tree, df, filename, col1, col2):
    """
    Writes a Newick tree, a space, and two DataFrame columns to a file.

    :param tree: Newick tree string.
    :param df: Pandas DataFrame.
    :param filename: Output file name.
    :param col1: First column name from DataFrame.
    :param col2: Second column name from DataFrame.
    """
    with open(filename, 'w') as f:
        # Write the Newick tree
        f.write(tree + '\n\n')  # Newick tree followed by a newline and a space

        # Write the specified DataFrame columns
        df[[col1, col2]].to_csv(f, sep='\t', index=False,header=None)

# Example usage
newick_tree = fixed_pruned_tree.write()


write_tree_and_dataframe_to_file(newick_tree, combined_df, '/allen/programs/celltypes/workgroups/rnaseqanalysis/EvoGen/Team/Matthew/genome/hal/26_plus_genomes/26pg.txt', 'Species', 'FASTA Path')
